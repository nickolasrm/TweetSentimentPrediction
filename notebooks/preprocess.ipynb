# %% [markdown]
# # preprocess

# %%
import pandas as pd

# %%
# %reload_kedro
# Out:
# 2022-06-17 02:10:13,675 - kedro.extras.extensions.ipython - INFO - No path argument was provided. Using: C:\Users\nicko\Projects\TweetSentimentPrediction
# 2022-06-17 02:10:14,508 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2022-06-17 02:10:14,681 - kedro.extras.extensions.ipython - INFO - ** Kedro project Tweet Sentiment Prediction
# 2022-06-17 02:10:14,683 - kedro.extras.extensions.ipython - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`

# %% [markdown]
# ## tweets dataset

# %%
raw_tweets = catalog.load('raw_tweets')
# Out:
# 2022-06-18 20:02:23,711 - kedro.io.data_catalog - INFO - Loading data from `raw_tweets` (ParquetDataSet)...

# %%
raw_tweets
# Out:
#          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  \
# 0        0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1        0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2        0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3        0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4        0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# ...     ..         ...                           ...       ...
# 1599994  4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599995  4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996  4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997  4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998  4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#          _TheSpecialOne_  \
# 0          scotthamilton
# 1               mattycus
# 2                ElleCTF
# 3                 Karoli
# 4               joy_wolf
# ...                  ...
# ...

# %% [markdown]
# ### adding header to the dataset

# %%
raw_tweets.columns = ['target', 'ids', 'date', 'flag', 'user', 'text']
raw_tweets
# Out:
#          target         ids                          date      flag  \
# 0             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599994       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599995       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %% [markdown]
# ### balancing dataset targets

# %%
raw_tweets['target'].value_counts()
# Out:
# 4    800000
# 0    799999
# Name: target, dtype: int64

# %% [markdown]
# ### lowercasing dataset

# %%
for col in raw_tweets:
    s = raw_tweets[col]
    if pd.api.types.is_object_dtype(s):
        s = s.str.lower()
    raw_tweets[col] = s
raw_tweets
# Out:
#          target         ids                          date      flag  \
# 0             0  1467810672  mon apr 06 22:19:49 pdt 2009  no_query
# 1             0  1467810917  mon apr 06 22:19:53 pdt 2009  no_query
# 2             0  1467811184  mon apr 06 22:19:57 pdt 2009  no_query
# 3             0  1467811193  mon apr 06 22:19:57 pdt 2009  no_query
# 4             0  1467811372  mon apr 06 22:20:00 pdt 2009  no_query
# ...         ...         ...                           ...       ...
# 1599994       4  2193601966  tue jun 16 08:40:49 pdt 2009  no_query
# 1599995       4  2193601969  tue jun 16 08:40:49 pdt 2009  no_query
# 1599996       4  2193601991  tue jun 16 08:40:49 pdt 2009  no_query
# 1599997       4  2193602064  tue jun 16 08:40:49 pdt 2009  no_query
# 1599998       4  2193602129  tue jun 16 08:40:50 pdt 2009  no_query
#
#                     user                                               text
# ...

# %%
# Out:
#          target         ids                          date      flag  \
# 0             0  1467810672  mon apr 06 22:19:49 pdt 2009  no_query
# 1             0  1467810917  mon apr 06 22:19:53 pdt 2009  no_query
# 2             0  1467811184  mon apr 06 22:19:57 pdt 2009  no_query
# 3             0  1467811193  mon apr 06 22:19:57 pdt 2009  no_query
# 4             0  1467811372  mon apr 06 22:20:00 pdt 2009  no_query
# ...         ...         ...                           ...       ...
# 1599994       4  2193601966  tue jun 16 08:40:49 pdt 2009  no_query
# 1599995       4  2193601969  tue jun 16 08:40:49 pdt 2009  no_query
# 1599996       4  2193601991  tue jun 16 08:40:49 pdt 2009  no_query
# 1599997       4  2193602064  tue jun 16 08:40:49 pdt 2009  no_query
# 1599998       4  2193602129  tue jun 16 08:40:50 pdt 2009  no_query
#
#                     user                                               text
# ...
